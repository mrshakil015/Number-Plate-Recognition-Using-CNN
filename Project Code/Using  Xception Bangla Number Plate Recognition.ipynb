# %% [markdown]
# ##**Xception**

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.optimizers import Adam
import xml.etree.ElementTree as ET
from tensorflow.keras.regularizers import l2
import pickle

# Define the input shape and batch size
input_shape = (224, 224, 3)
batch_size = 32

# Define the base model
Xception_base_model = Xception(input_shape=input_shape, include_top=False, weights='imagenet')

# Freeze the layers of the base model
for layer in Xception_base_model.layers:
    layer.trainable = False

# Unfreeze the last convolutional block of the base model
for layer in Xception_base_model.layers[-4:]:
    layer.trainable = True
# Add a custom head to the base model
x = Xception_base_model.output
x = Flatten()(x)
x = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(x)
x = Dense(64, activation='relu', kernel_regularizer=l2(0.01))(x)
x = Dense(4, activation='linear')(x)
model = Model(inputs=Xception_base_model.input, outputs=x)
# Compile the model

optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mse', optimizer=optimizer, metrics=['accuracy'])

# Callback to the model
save_Xception_model = tf.keras.callbacks.ModelCheckpoint(
    "/content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5", 
    monitor='accuracy', 
    save_best_only=True, 
    verbose=1
)
# Directory Path
training_directory = '/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/train'
validation_directory = '/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/valid'

# Image Generator function
def image_generator(directory_path, batch_size, input_shape):
    while True:
        data = []
        train_annotation = []
        for filename in os.listdir(directory_path):
            if filename.split('.')[-1] in ['jpeg', 'jpg', 'png']:
                
                image_path = os.path.join(directory_path, filename)

                xml_path = os.path.join(directory_path, filename[:-4] +'.xml')

                tree = ET.parse(xml_path)
                root = tree.getroot()

                # Check boundbox
                boundingbox = root.find('object/bndbox')
                if boundingbox is not None:
                    X_min = int(boundingbox.find('xmin').text)
                    X_max = int(boundingbox.find('xmax').text)
                    Y_min = int(boundingbox.find('ymin').text)
                    Y_max = int(boundingbox.find('ymax').text)
                    train_annotation.append([X_min, Y_min, X_max, Y_max])

                    # Load image
                    image = cv2.imread(image_path)
                    image = cv2.resize(image, input_shape[:2])
                    data.append(image)

                    if len(data) == batch_size:
                        yield np.array(data), np.array(train_annotation) * 0.35
                        data = []
                        train_annotation = []

        if len(data) > 0:
            yield np.array(data), np.array(train_annotation) * 0.35
            
# Evaluate the performance on the validation set
train_generator = image_generator(training_directory, batch_size, input_shape)
training_steps = len(os.listdir(training_directory)) // batch_size

val_generator = image_generator(validation_directory, batch_size, input_shape)
val_steps = len(os.listdir(validation_directory)) // batch_size

# Train the model
Xception_model_history = model.fit(train_generator,
                                      steps_per_epoch=training_steps,
                                      epochs=100,
                                      verbose=1,
                                      validation_data=val_generator,
                                      validation_steps=val_steps,
                                      callbacks=[save_Xception_model])


# Save the history variable to a file in your Google Drive
with open('/content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/Xception_model_history.pkl', 'wb') as f:
    pickle.dump(Xception_model_history.history, f)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 1s 0us/step
# Epoch 1/100
# 62/62 [==============================] - ETA: 0s - loss: 5753.5234 - accuracy: 0.4542
# Epoch 1: accuracy improved from -inf to 0.45422, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 52s 574ms/step - loss: 5753.5234 - accuracy: 0.4542 - val_loss: 3329.9307 - val_accuracy: 0.7604
# Epoch 2/100
# 62/62 [==============================] - ETA: 0s - loss: 1681.2158 - accuracy: 0.6740
# Epoch 2: accuracy improved from 0.45422 to 0.67402, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 30s 496ms/step - loss: 1681.2158 - accuracy: 0.6740 - val_loss: 1941.5039 - val_accuracy: 0.7431
# Epoch 3/100
# 62/62 [==============================] - ETA: 0s - loss: 1295.0503 - accuracy: 0.6812
# Epoch 3: accuracy improved from 0.67402 to 0.68121, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 28s 454ms/step - loss: 1295.0503 - accuracy: 0.6812 - val_loss: 1300.4028 - val_accuracy: 0.7569
# Epoch 4/100
# 62/62 [==============================] - ETA: 0s - loss: 979.4630 - accuracy: 0.7156
# Epoch 4: accuracy improved from 0.68121 to 0.71561, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 29s 480ms/step - loss: 979.4630 - accuracy: 0.7156 - val_loss: 910.9517 - val_accuracy: 0.7674
# Epoch 5/100
# 62/62 [==============================] - ETA: 0s - loss: 720.9940 - accuracy: 0.7562
# Epoch 5: accuracy improved from 0.71561 to 0.75616, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 33s 540ms/step - loss: 720.9940 - accuracy: 0.7562 - val_loss: 817.9351 - val_accuracy: 0.7465
# Epoch 6/100
# 62/62 [==============================] - ETA: 0s - loss: 585.4661 - accuracy: 0.7931
# Epoch 6: accuracy improved from 0.75616 to 0.79312, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 33s 545ms/step - loss: 585.4661 - accuracy: 0.7931 - val_loss: 751.8528 - val_accuracy: 0.7257
# Epoch 7/100
# 62/62 [==============================] - ETA: 0s - loss: 480.4375 - accuracy: 0.8219
# Epoch 7: accuracy improved from 0.79312 to 0.82187, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 28s 456ms/step - loss: 480.4375 - accuracy: 0.8219 - val_loss: 690.2014 - val_accuracy: 0.7431
# Epoch 8/100
# 62/62 [==============================] - ETA: 0s - loss: 404.0583 - accuracy: 0.8378
# Epoch 8: accuracy improved from 0.82187 to 0.83778, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 29s 470ms/step - loss: 404.0583 - accuracy: 0.8378 - val_loss: 657.0002 - val_accuracy: 0.7326
# Epoch 9/100
# 62/62 [==============================] - ETA: 0s - loss: 338.8360 - accuracy: 0.8552
# Epoch 9: accuracy improved from 0.83778 to 0.85524, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 28s 458ms/step - loss: 338.8360 - accuracy: 0.8552 - val_loss: 650.5140 - val_accuracy: 0.7396
# Epoch 10/100
# 62/62 [==============================] - ETA: 0s - loss: 276.8282 - accuracy: 0.8650
# Epoch 10: accuracy improved from 0.85524 to 0.86499, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 28s 455ms/step - loss: 276.8282 - accuracy: 0.8650 - val_loss: 682.4983 - val_accuracy: 0.7431
# Epoch 11/100
# 62/62 [==============================] - ETA: 0s - loss: 228.1427 - accuracy: 0.8763
# Epoch 11: accuracy improved from 0.86499 to 0.87628, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 28s 450ms/step - loss: 228.1427 - accuracy: 0.8763 - val_loss: 725.8607 - val_accuracy: 0.7361
# Epoch 12/100
# 62/62 [==============================] - ETA: 0s - loss: 180.5516 - accuracy: 0.8927
# Epoch 12: accuracy improved from 0.87628 to 0.89271, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 29s 471ms/step - loss: 180.5516 - accuracy: 0.8927 - val_loss: 733.4564 - val_accuracy: 0.7361
# Epoch 13/100
# 62/62 [==============================] - ETA: 0s - loss: 139.8059 - accuracy: 0.9086
# Epoch 13: accuracy improved from 0.89271 to 0.90862, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 34s 555ms/step - loss: 139.8059 - accuracy: 0.9086 - val_loss: 723.2371 - val_accuracy: 0.7326
# Epoch 14/100
# 62/62 [==============================] - ETA: 0s - loss: 105.5881 - accuracy: 0.9225
# Epoch 14: accuracy improved from 0.90862 to 0.92248, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 33s 537ms/step - loss: 105.5881 - accuracy: 0.9225 - val_loss: 695.0734 - val_accuracy: 0.7465
# Epoch 15/100
# 62/62 [==============================] - ETA: 0s - loss: 79.9804 - accuracy: 0.9374
# Epoch 15: accuracy improved from 0.92248 to 0.93737, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 27s 445ms/step - loss: 79.9804 - accuracy: 0.9374 - val_loss: 655.0920 - val_accuracy: 0.7465
# Epoch 16/100
# 62/62 [==============================] - ETA: 0s - loss: 60.3599 - accuracy: 0.9420
# Epoch 16: accuracy improved from 0.93737 to 0.94199, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 29s 473ms/step - loss: 60.3599 - accuracy: 0.9420 - val_loss: 629.3327 - val_accuracy: 0.7500
# Epoch 17/100
# 62/62 [==============================] - ETA: 0s - loss: 55.8122 - accuracy: 0.9451
# Epoch 17: accuracy improved from 0.94199 to 0.94507, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 29s 466ms/step - loss: 55.8122 - accuracy: 0.9451 - val_loss: 631.3000 - val_accuracy: 0.7604
# Epoch 18/100
# 62/62 [==============================] - ETA: 0s - loss: 54.8378 - accuracy: 0.9353
# Epoch 18: accuracy did not improve from 0.94507
# 62/62 [==============================] - 29s 474ms/step - loss: 54.8378 - accuracy: 0.9353 - val_loss: 634.5564 - val_accuracy: 0.7743
# Epoch 19/100
# 62/62 [==============================] - ETA: 0s - loss: 39.4840 - accuracy: 0.9533
# Epoch 19: accuracy improved from 0.94507 to 0.95329, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 28s 460ms/step - loss: 39.4840 - accuracy: 0.9533 - val_loss: 649.3212 - val_accuracy: 0.7465
# Epoch 20/100
# 62/62 [==============================] - ETA: 0s - loss: 38.6002 - accuracy: 0.9440
# Epoch 20: accuracy did not improve from 0.95329
# 62/62 [==============================] - 29s 470ms/step - loss: 38.6002 - accuracy: 0.9440 - val_loss: 647.4347 - val_accuracy: 0.7326
# Epoch 21/100
# 62/62 [==============================] - ETA: 0s - loss: 49.7175 - accuracy: 0.9281
# Epoch 21: accuracy did not improve from 0.95329
# 62/62 [==============================] - 26s 418ms/step - loss: 49.7175 - accuracy: 0.9281 - val_loss: 685.3352 - val_accuracy: 0.7708
# Epoch 22/100
# 62/62 [==============================] - ETA: 0s - loss: 100.6890 - accuracy: 0.8866
# Epoch 22: accuracy did not improve from 0.95329
# 62/62 [==============================] - 24s 399ms/step - loss: 100.6890 - accuracy: 0.8866 - val_loss: 884.5449 - val_accuracy: 0.7257
# Epoch 23/100
# 62/62 [==============================] - ETA: 0s - loss: 130.7803 - accuracy: 0.8789
# Epoch 23: accuracy did not improve from 0.95329
# 62/62 [==============================] - 24s 390ms/step - loss: 130.7803 - accuracy: 0.8789 - val_loss: 747.1950 - val_accuracy: 0.7743
# Epoch 24/100
# 62/62 [==============================] - ETA: 0s - loss: 87.2153 - accuracy: 0.9497
# Epoch 24: accuracy did not improve from 0.95329
# 62/62 [==============================] - 24s 391ms/step - loss: 87.2153 - accuracy: 0.9497 - val_loss: 602.0305 - val_accuracy: 0.7465
# Epoch 25/100
# 62/62 [==============================] - ETA: 0s - loss: 38.4481 - accuracy: 0.9594
# Epoch 25: accuracy improved from 0.95329 to 0.95945, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 27s 436ms/step - loss: 38.4481 - accuracy: 0.9594 - val_loss: 908.4849 - val_accuracy: 0.7465
# Epoch 26/100
# 62/62 [==============================] - ETA: 0s - loss: 30.3818 - accuracy: 0.9630
# Epoch 26: accuracy improved from 0.95945 to 0.96304, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 29s 466ms/step - loss: 30.3818 - accuracy: 0.9630 - val_loss: 780.5614 - val_accuracy: 0.7396
# Epoch 27/100
# 62/62 [==============================] - ETA: 0s - loss: 32.1748 - accuracy: 0.9646
# Epoch 27: accuracy improved from 0.96304 to 0.96458, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 27s 448ms/step - loss: 32.1748 - accuracy: 0.9646 - val_loss: 768.9116 - val_accuracy: 0.7396
# Epoch 28/100
# 62/62 [==============================] - ETA: 0s - loss: 32.8881 - accuracy: 0.9641
# Epoch 28: accuracy did not improve from 0.96458
# 62/62 [==============================] - 25s 400ms/step - loss: 32.8881 - accuracy: 0.9641 - val_loss: 671.8717 - val_accuracy: 0.7604
# Epoch 29/100
# 62/62 [==============================] - ETA: 0s - loss: 35.5373 - accuracy: 0.9615
# Epoch 29: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 394ms/step - loss: 35.5373 - accuracy: 0.9615 - val_loss: 647.7632 - val_accuracy: 0.7674
# Epoch 30/100
# 62/62 [==============================] - ETA: 0s - loss: 42.2648 - accuracy: 0.9615
# Epoch 30: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 384ms/step - loss: 42.2648 - accuracy: 0.9615 - val_loss: 744.0598 - val_accuracy: 0.7569
# Epoch 31/100
# 62/62 [==============================] - ETA: 0s - loss: 49.5349 - accuracy: 0.9589
# Epoch 31: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 398ms/step - loss: 49.5349 - accuracy: 0.9589 - val_loss: 1014.2219 - val_accuracy: 0.7257
# Epoch 32/100
# 62/62 [==============================] - ETA: 0s - loss: 65.5211 - accuracy: 0.9497
# Epoch 32: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 393ms/step - loss: 65.5211 - accuracy: 0.9497 - val_loss: 1096.6711 - val_accuracy: 0.7743
# Epoch 33/100
# 62/62 [==============================] - ETA: 0s - loss: 92.6988 - accuracy: 0.9461
# Epoch 33: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 394ms/step - loss: 92.6988 - accuracy: 0.9461 - val_loss: 953.0479 - val_accuracy: 0.7292
# Epoch 34/100
# 62/62 [==============================] - ETA: 0s - loss: 142.9819 - accuracy: 0.9266
# Epoch 34: accuracy did not improve from 0.96458
# 62/62 [==============================] - 28s 458ms/step - loss: 142.9819 - accuracy: 0.9266 - val_loss: 683.4789 - val_accuracy: 0.7917
# Epoch 35/100
# 62/62 [==============================] - ETA: 0s - loss: 211.3450 - accuracy: 0.9163
# Epoch 35: accuracy did not improve from 0.96458
# 62/62 [==============================] - 28s 457ms/step - loss: 211.3450 - accuracy: 0.9163 - val_loss: 1338.8590 - val_accuracy: 0.7292
# Epoch 36/100
# 62/62 [==============================] - ETA: 0s - loss: 292.6613 - accuracy: 0.8989
# Epoch 36: accuracy did not improve from 0.96458
# 62/62 [==============================] - 25s 407ms/step - loss: 292.6613 - accuracy: 0.8989 - val_loss: 2328.2358 - val_accuracy: 0.7604
# Epoch 37/100
# 62/62 [==============================] - ETA: 0s - loss: 373.3517 - accuracy: 0.8737
# Epoch 37: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 384ms/step - loss: 373.3517 - accuracy: 0.8737 - val_loss: 842.9528 - val_accuracy: 0.7951
# Epoch 38/100
# 62/62 [==============================] - ETA: 0s - loss: 305.9112 - accuracy: 0.8763
# Epoch 38: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 387ms/step - loss: 305.9112 - accuracy: 0.8763 - val_loss: 990.3637 - val_accuracy: 0.7292
# Epoch 39/100
# 62/62 [==============================] - ETA: 0s - loss: 226.2165 - accuracy: 0.8794
# Epoch 39: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 398ms/step - loss: 226.2165 - accuracy: 0.8794 - val_loss: 838.3596 - val_accuracy: 0.7604
# Epoch 40/100
# 62/62 [==============================] - ETA: 0s - loss: 170.2401 - accuracy: 0.8912
# Epoch 40: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 389ms/step - loss: 170.2401 - accuracy: 0.8912 - val_loss: 810.1363 - val_accuracy: 0.7674
# Epoch 41/100
# 62/62 [==============================] - ETA: 0s - loss: 138.3240 - accuracy: 0.9066
# Epoch 41: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 398ms/step - loss: 138.3240 - accuracy: 0.9066 - val_loss: 818.7634 - val_accuracy: 0.7812
# Epoch 42/100
# 62/62 [==============================] - ETA: 0s - loss: 115.5214 - accuracy: 0.9127
# Epoch 42: accuracy did not improve from 0.96458
# 62/62 [==============================] - 23s 381ms/step - loss: 115.5214 - accuracy: 0.9127 - val_loss: 874.9670 - val_accuracy: 0.7188
# Epoch 43/100
# 62/62 [==============================] - ETA: 0s - loss: 92.5754 - accuracy: 0.9081
# Epoch 43: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 393ms/step - loss: 92.5754 - accuracy: 0.9081 - val_loss: 808.2562 - val_accuracy: 0.7188
# Epoch 44/100
# 62/62 [==============================] - ETA: 0s - loss: 81.5822 - accuracy: 0.9050
# Epoch 44: accuracy did not improve from 0.96458
# 62/62 [==============================] - 28s 458ms/step - loss: 81.5822 - accuracy: 0.9050 - val_loss: 648.3897 - val_accuracy: 0.7743
# Epoch 45/100
# 62/62 [==============================] - ETA: 0s - loss: 75.0674 - accuracy: 0.9045
# Epoch 45: accuracy did not improve from 0.96458
# 62/62 [==============================] - 28s 463ms/step - loss: 75.0674 - accuracy: 0.9045 - val_loss: 641.2452 - val_accuracy: 0.7743
# Epoch 46/100
# 62/62 [==============================] - ETA: 0s - loss: 76.1856 - accuracy: 0.9020
# Epoch 46: accuracy did not improve from 0.96458
# 62/62 [==============================] - 30s 481ms/step - loss: 76.1856 - accuracy: 0.9020 - val_loss: 859.0278 - val_accuracy: 0.7882
# Epoch 47/100
# 62/62 [==============================] - ETA: 0s - loss: 85.8132 - accuracy: 0.8958
# Epoch 47: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 389ms/step - loss: 85.8132 - accuracy: 0.8958 - val_loss: 972.9203 - val_accuracy: 0.7639
# Epoch 48/100
# 62/62 [==============================] - ETA: 0s - loss: 99.4971 - accuracy: 0.8891
# Epoch 48: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 389ms/step - loss: 99.4971 - accuracy: 0.8891 - val_loss: 811.3268 - val_accuracy: 0.7778
# Epoch 49/100
# 62/62 [==============================] - ETA: 0s - loss: 136.0527 - accuracy: 0.8693
# Epoch 49: accuracy did not improve from 0.96458
# 62/62 [==============================] - 28s 458ms/step - loss: 136.0527 - accuracy: 0.8693 - val_loss: 610.5702 - val_accuracy: 0.7569
# Epoch 50/100
# 62/62 [==============================] - ETA: 0s - loss: 151.7154 - accuracy: 0.8686
# Epoch 50: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 385ms/step - loss: 151.7154 - accuracy: 0.8686 - val_loss: 817.2804 - val_accuracy: 0.7188
# Epoch 51/100
# 62/62 [==============================] - ETA: 0s - loss: 139.8219 - accuracy: 0.8830
# Epoch 51: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 392ms/step - loss: 139.8219 - accuracy: 0.8830 - val_loss: 770.3027 - val_accuracy: 0.7535
# Epoch 52/100
# 62/62 [==============================] - ETA: 0s - loss: 108.6411 - accuracy: 0.8978
# Epoch 52: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 389ms/step - loss: 108.6411 - accuracy: 0.8978 - val_loss: 604.8212 - val_accuracy: 0.7569
# Epoch 53/100
# 62/62 [==============================] - ETA: 0s - loss: 76.8857 - accuracy: 0.9163
# Epoch 53: accuracy did not improve from 0.96458
# 62/62 [==============================] - 24s 385ms/step - loss: 76.8857 - accuracy: 0.9163 - val_loss: 605.6733 - val_accuracy: 0.7847
# Epoch 54/100
# 62/62 [==============================] - ETA: 0s - loss: 60.8197 - accuracy: 0.9384
# Epoch 54: accuracy did not improve from 0.96458
# 62/62 [==============================] - 88s 1s/step - loss: 60.8197 - accuracy: 0.9384 - val_loss: 687.9271 - val_accuracy: 0.7882
# Epoch 55/100
# 62/62 [==============================] - ETA: 0s - loss: 59.1654 - accuracy: 0.9517
# Epoch 55: accuracy did not improve from 0.96458
# 62/62 [==============================] - 28s 458ms/step - loss: 59.1654 - accuracy: 0.9517 - val_loss: 631.5227 - val_accuracy: 0.7812
# Epoch 56/100
# 62/62 [==============================] - ETA: 0s - loss: 59.6639 - accuracy: 0.9579
# Epoch 56: accuracy did not improve from 0.96458
# 62/62 [==============================] - 28s 457ms/step - loss: 59.6639 - accuracy: 0.9579 - val_loss: 611.9927 - val_accuracy: 0.7743
# Epoch 57/100
# 62/62 [==============================] - ETA: 0s - loss: 51.4952 - accuracy: 0.9641
# Epoch 57: accuracy did not improve from 0.96458
# 62/62 [==============================] - 28s 455ms/step - loss: 51.4952 - accuracy: 0.9641 - val_loss: 661.7247 - val_accuracy: 0.7708
# Epoch 58/100
# 62/62 [==============================] - ETA: 0s - loss: 44.1176 - accuracy: 0.9702
# Epoch 58: accuracy improved from 0.96458 to 0.97023, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 31s 504ms/step - loss: 44.1176 - accuracy: 0.9702 - val_loss: 610.5580 - val_accuracy: 0.7604
# Epoch 59/100
# 62/62 [==============================] - ETA: 0s - loss: 41.7141 - accuracy: 0.9743
# Epoch 59: accuracy improved from 0.97023 to 0.97433, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 33s 546ms/step - loss: 41.7141 - accuracy: 0.9743 - val_loss: 651.7429 - val_accuracy: 0.7674
# Epoch 60/100
# 62/62 [==============================] - ETA: 0s - loss: 41.2794 - accuracy: 0.9769
# Epoch 60: accuracy improved from 0.97433 to 0.97690, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 31s 512ms/step - loss: 41.2794 - accuracy: 0.9769 - val_loss: 689.8074 - val_accuracy: 0.7778
# Epoch 61/100
# 62/62 [==============================] - ETA: 0s - loss: 41.1480 - accuracy: 0.9790
# Epoch 61: accuracy improved from 0.97690 to 0.97895, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5
# 62/62 [==============================] - 32s 528ms/step - loss: 41.1480 - accuracy: 0.9790 - val_loss: 620.8306 - val_accuracy: 0.7708
# Epoch 62/100
# 62/62 [==============================] - ETA: 0s - loss: 40.9027 - accuracy: 0.9738
# Epoch 62: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 398ms/step - loss: 40.9027 - accuracy: 0.9738 - val_loss: 622.0725 - val_accuracy: 0.7708
# Epoch 63/100
# 62/62 [==============================] - ETA: 0s - loss: 36.0340 - accuracy: 0.9713
# Epoch 63: accuracy did not improve from 0.97895
# 62/62 [==============================] - 30s 491ms/step - loss: 36.0340 - accuracy: 0.9713 - val_loss: 662.5311 - val_accuracy: 0.7778
# Epoch 64/100
# 62/62 [==============================] - ETA: 0s - loss: 33.3462 - accuracy: 0.9677
# Epoch 64: accuracy did not improve from 0.97895
# 62/62 [==============================] - 23s 377ms/step - loss: 33.3462 - accuracy: 0.9677 - val_loss: 623.2693 - val_accuracy: 0.7847
# Epoch 65/100
# 62/62 [==============================] - ETA: 0s - loss: 35.6199 - accuracy: 0.9654
# Epoch 65: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 396ms/step - loss: 35.6199 - accuracy: 0.9654 - val_loss: 581.6741 - val_accuracy: 0.7639
# Epoch 66/100
# 62/62 [==============================] - ETA: 0s - loss: 39.3369 - accuracy: 0.9661
# Epoch 66: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 392ms/step - loss: 39.3369 - accuracy: 0.9661 - val_loss: 689.4771 - val_accuracy: 0.7917
# Epoch 67/100
# 62/62 [==============================] - ETA: 0s - loss: 43.7604 - accuracy: 0.9707
# Epoch 67: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 384ms/step - loss: 43.7604 - accuracy: 0.9707 - val_loss: 674.6392 - val_accuracy: 0.7917
# Epoch 68/100
# 62/62 [==============================] - ETA: 0s - loss: 47.2011 - accuracy: 0.9636
# Epoch 68: accuracy did not improve from 0.97895
# 62/62 [==============================] - 25s 400ms/step - loss: 47.2011 - accuracy: 0.9636 - val_loss: 644.5770 - val_accuracy: 0.7917
# Epoch 69/100
# 62/62 [==============================] - ETA: 0s - loss: 47.0570 - accuracy: 0.9620
# Epoch 69: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 389ms/step - loss: 47.0570 - accuracy: 0.9620 - val_loss: 662.3323 - val_accuracy: 0.7639
# Epoch 70/100
# 62/62 [==============================] - ETA: 0s - loss: 44.2799 - accuracy: 0.9559
# Epoch 70: accuracy did not improve from 0.97895
# 62/62 [==============================] - 28s 458ms/step - loss: 44.2799 - accuracy: 0.9559 - val_loss: 688.5045 - val_accuracy: 0.7500
# Epoch 71/100
# 62/62 [==============================] - ETA: 0s - loss: 42.4624 - accuracy: 0.9507
# Epoch 71: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 386ms/step - loss: 42.4624 - accuracy: 0.9507 - val_loss: 714.5522 - val_accuracy: 0.7535
# Epoch 72/100
# 62/62 [==============================] - ETA: 0s - loss: 46.2819 - accuracy: 0.9538
# Epoch 72: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 386ms/step - loss: 46.2819 - accuracy: 0.9538 - val_loss: 650.7457 - val_accuracy: 0.7882
# Epoch 73/100
# 62/62 [==============================] - ETA: 0s - loss: 48.0796 - accuracy: 0.9502
# Epoch 73: accuracy did not improve from 0.97895
# 62/62 [==============================] - 29s 480ms/step - loss: 48.0796 - accuracy: 0.9502 - val_loss: 630.2605 - val_accuracy: 0.7812
# Epoch 74/100
# 62/62 [==============================] - ETA: 0s - loss: 46.6341 - accuracy: 0.9461
# Epoch 74: accuracy did not improve from 0.97895
# 62/62 [==============================] - 28s 455ms/step - loss: 46.6341 - accuracy: 0.9461 - val_loss: 614.7152 - val_accuracy: 0.7674
# Epoch 75/100
# 62/62 [==============================] - ETA: 0s - loss: 42.6064 - accuracy: 0.9415
# Epoch 75: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 387ms/step - loss: 42.6064 - accuracy: 0.9415 - val_loss: 692.0533 - val_accuracy: 0.7674
# Epoch 76/100
# 62/62 [==============================] - ETA: 0s - loss: 43.5497 - accuracy: 0.9440
# Epoch 76: accuracy did not improve from 0.97895
# 62/62 [==============================] - 23s 374ms/step - loss: 43.5497 - accuracy: 0.9440 - val_loss: 717.6405 - val_accuracy: 0.7917
# Epoch 77/100
# 62/62 [==============================] - ETA: 0s - loss: 44.1150 - accuracy: 0.9548
# Epoch 77: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 389ms/step - loss: 44.1150 - accuracy: 0.9548 - val_loss: 627.9879 - val_accuracy: 0.7812
# Epoch 78/100
# 62/62 [==============================] - ETA: 0s - loss: 44.5158 - accuracy: 0.9584
# Epoch 78: accuracy did not improve from 0.97895
# 62/62 [==============================] - 25s 416ms/step - loss: 44.5158 - accuracy: 0.9584 - val_loss: 665.0856 - val_accuracy: 0.7674
# Epoch 79/100
# 62/62 [==============================] - ETA: 0s - loss: 52.3273 - accuracy: 0.9641
# Epoch 79: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 390ms/step - loss: 52.3273 - accuracy: 0.9641 - val_loss: 730.5439 - val_accuracy: 0.7743
# Epoch 80/100
# 62/62 [==============================] - ETA: 0s - loss: 68.8426 - accuracy: 0.9677
# Epoch 80: accuracy did not improve from 0.97895
# 62/62 [==============================] - 23s 372ms/step - loss: 68.8426 - accuracy: 0.9677 - val_loss: 668.1456 - val_accuracy: 0.7917
# Epoch 81/100
# 62/62 [==============================] - ETA: 0s - loss: 84.2556 - accuracy: 0.9629
# Epoch 81: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 390ms/step - loss: 84.2556 - accuracy: 0.9629 - val_loss: 671.2608 - val_accuracy: 0.7847
# Epoch 82/100
# 62/62 [==============================] - ETA: 0s - loss: 86.8581 - accuracy: 0.9605
# Epoch 82: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 389ms/step - loss: 86.8581 - accuracy: 0.9605 - val_loss: 921.5974 - val_accuracy: 0.7743
# Epoch 83/100
# 62/62 [==============================] - ETA: 0s - loss: 90.2670 - accuracy: 0.9517
# Epoch 83: accuracy did not improve from 0.97895
# 62/62 [==============================] - 29s 473ms/step - loss: 90.2670 - accuracy: 0.9517 - val_loss: 676.9364 - val_accuracy: 0.7604
# Epoch 84/100
# 62/62 [==============================] - ETA: 0s - loss: 91.9565 - accuracy: 0.9451
# Epoch 84: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 387ms/step - loss: 91.9565 - accuracy: 0.9451 - val_loss: 735.2264 - val_accuracy: 0.7639
# Epoch 85/100
# 62/62 [==============================] - ETA: 0s - loss: 86.7282 - accuracy: 0.9369
# Epoch 85: accuracy did not improve from 0.97895
# 62/62 [==============================] - 23s 373ms/step - loss: 86.7282 - accuracy: 0.9369 - val_loss: 831.1345 - val_accuracy: 0.7708
# Epoch 86/100
# 62/62 [==============================] - ETA: 0s - loss: 77.4133 - accuracy: 0.9204
# Epoch 86: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 390ms/step - loss: 77.4133 - accuracy: 0.9204 - val_loss: 744.1401 - val_accuracy: 0.7257
# Epoch 87/100
# 62/62 [==============================] - ETA: 0s - loss: 66.2737 - accuracy: 0.9256
# Epoch 87: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 388ms/step - loss: 66.2737 - accuracy: 0.9256 - val_loss: 735.5943 - val_accuracy: 0.7569
# Epoch 88/100
# 62/62 [==============================] - ETA: 0s - loss: 57.9895 - accuracy: 0.9317
# Epoch 88: accuracy did not improve from 0.97895
# 62/62 [==============================] - 25s 408ms/step - loss: 57.9895 - accuracy: 0.9317 - val_loss: 722.8308 - val_accuracy: 0.7847
# Epoch 89/100
# 62/62 [==============================] - ETA: 0s - loss: 57.5854 - accuracy: 0.9405
# Epoch 89: accuracy did not improve from 0.97895
# 62/62 [==============================] - 23s 375ms/step - loss: 57.5854 - accuracy: 0.9405 - val_loss: 693.9998 - val_accuracy: 0.7778
# Epoch 90/100
# 62/62 [==============================] - ETA: 0s - loss: 53.0381 - accuracy: 0.9523
# Epoch 90: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 385ms/step - loss: 53.0381 - accuracy: 0.9523 - val_loss: 836.8425 - val_accuracy: 0.7812
# Epoch 91/100
# 62/62 [==============================] - ETA: 0s - loss: 49.0784 - accuracy: 0.9605
# Epoch 91: accuracy did not improve from 0.97895
# 62/62 [==============================] - 29s 465ms/step - loss: 49.0784 - accuracy: 0.9605 - val_loss: 788.8845 - val_accuracy: 0.7743
# Epoch 92/100
# 62/62 [==============================] - ETA: 0s - loss: 48.5160 - accuracy: 0.9656
# Epoch 92: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 389ms/step - loss: 48.5160 - accuracy: 0.9656 - val_loss: 657.5667 - val_accuracy: 0.7847
# Epoch 93/100
# 62/62 [==============================] - ETA: 0s - loss: 49.9089 - accuracy: 0.9636
# Epoch 93: accuracy did not improve from 0.97895
# 62/62 [==============================] - 25s 407ms/step - loss: 49.9089 - accuracy: 0.9636 - val_loss: 728.2407 - val_accuracy: 0.7569
# Epoch 94/100
# 62/62 [==============================] - ETA: 0s - loss: 53.1385 - accuracy: 0.9625
# Epoch 94: accuracy did not improve from 0.97895
# 62/62 [==============================] - 23s 377ms/step - loss: 53.1385 - accuracy: 0.9625 - val_loss: 770.1298 - val_accuracy: 0.7257
# Epoch 95/100
# 62/62 [==============================] - ETA: 0s - loss: 53.0850 - accuracy: 0.9502
# Epoch 95: accuracy did not improve from 0.97895
# 62/62 [==============================] - 23s 380ms/step - loss: 53.0850 - accuracy: 0.9502 - val_loss: 963.9347 - val_accuracy: 0.7500
# Epoch 96/100
# 62/62 [==============================] - ETA: 0s - loss: 59.5907 - accuracy: 0.9415
# Epoch 96: accuracy did not improve from 0.97895
# 62/62 [==============================] - 24s 389ms/step - loss: 59.5907 - accuracy: 0.9415 - val_loss: 727.7406 - val_accuracy: 0.7708
# Epoch 97/100
# 62/62 [==============================] - ETA: 0s - loss: 61.8416 - accuracy: 0.9359
# Epoch 97: accuracy did not improve from 0.97895
# 62/62 [==============================] - 28s 459ms/step - loss: 61.8416 - accuracy: 0.9359 - val_loss: 636.4037 - val_accuracy: 0.7639
# Epoch 98/100
# 62/62 [==============================] - ETA: 0s - loss: 58.9406 - accuracy: 0.9271
# Epoch 98: accuracy did not improve from 0.97895
# 62/62 [==============================] - 28s 458ms/step - loss: 58.9406 - accuracy: 0.9271 - val_loss: 789.8494 - val_accuracy: 0.7743
# Epoch 99/100
# 62/62 [==============================] - ETA: 0s - loss: 59.1263 - accuracy: 0.9143
# Epoch 99: accuracy did not improve from 0.97895
# 62/62 [==============================] - 25s 403ms/step - loss: 59.1263 - accuracy: 0.9143 - val_loss: 906.7598 - val_accuracy: 0.7604
# Epoch 100/100
# 62/62 [==============================] - ETA: 0s - loss: 63.6460 - accuracy: 0.8937
# Epoch 100: accuracy did not improve from 0.97895
# 62/62 [==============================] - 28s 453ms/step - loss: 63.6460 - accuracy: 0.8937 - val_loss: 733.6327 - val_accuracy: 0.7743

# %% [markdown]
# ###**Test the model for detecting output**

# %%
import matplotlib.pyplot as plt

#Load model
XceptionModel = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/XceptionModel.h5')

# Directory Path
test_directory = r'/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/test'

# Data Generator for test set
test_generator = image_generator(test_directory, batch_size, input_shape)
images, annotations = next(test_generator)

model_predictions = XceptionModel.predict(images)
for i in range(0, len(images), 4):
    fig, axs = plt.subplots(1, 4, figsize=(20, 10))
    for j in range(4):
        if i+j >= len(images):
            break
        image = images[i+j].astype('uint8')
        annotation = annotations[i+j]
        pred = model_predictions[i+j]
        X_min, Y_min, X_max, Y_max = annotation.astype('int')
        X_min1, Y_min1, X_max1, Y_max1 = pred.astype('int')
        cv2.rectangle(image, (X_min, Y_min), (X_max, Y_max), (0, 255, 0), 2)
        cv2.rectangle(image, (X_min1, Y_min1), (X_max1, Y_max1), (255,0,0), 2)
        cv2.putText(image, 'Number Plate', (X_min1, Y_min1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)
        axs[j].imshow(image)
        axs[j].axis('off')
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ###**Performance Evaluation**

# %%
# Directory Path
training_directory = '/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/train'
validation_directory = '/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/valid'
test_directory = '/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/test'

#Data Generator
train_generator = image_generator(training_directory, batch_size, input_shape)
training_steps = len(os.listdir(training_directory)) // batch_size

val_generator = image_generator(validation_directory, batch_size, input_shape)
val_steps = len(os.listdir(validation_directory)) // batch_size

test_generator = image_generator(test_directory, batch_size, input_shape)
test_steps = len(os.listdir(test_directory)) // batch_size

# Evaluate the performance on the validation set

validation_loss, validation_accuracy = XceptionModel.evaluate(val_generator, steps=val_steps)

print("Validation Loss:", validation_loss)
print("Validation Accuracy:", validation_accuracy)

# Evaluate the performance on the training set
training_loss, training_accuracy = XceptionModel.evaluate(train_generator, steps=training_steps)

print("Training Loss:", training_loss)
print("Training Accuracy:", training_accuracy)

# Evaluate the performance on the test set
test_loss, test_accuracy = XceptionModel.evaluate(test_generator, steps=test_steps)
print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
# Out:
# 18/18 [==============================] - 6s 284ms/step - loss: 620.8304 - accuracy: 0.7708
# Validation Loss: 620.8304443359375
# Validation Accuracy: 0.7708333134651184
# 62/62 [==============================] - 20s 318ms/step - loss: 55.6167 - accuracy: 0.9578
# Training Loss: 55.61669921875
# Training Accuracy: 0.9577823281288147
# 9/9 [==============================] - 3s 374ms/step - loss: 639.5196 - accuracy: 0.7802
# Test loss: 639.5195922851562
# Test accuracy: 0.7802197933197021

# %% [markdown]
# ###**Visual Representation on Training and Validation**

# %%
import pickle

with open('/content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/Xception_model_history.pkl', 'rb') as f:
    history = pickle.load(f)

# Plot the accuracy over epochs
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accurracy', 'Validation Accurracy'], loc='upper left')
plt.show()

# Plot the loss over epochs
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper left')
plt.show()
