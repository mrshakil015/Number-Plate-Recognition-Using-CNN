# %% [markdown]
# #**MaxPool Model**

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import xml.etree.ElementTree as ET
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle

# Define the input shape and batch size
input_shape = (224, 224, 3)
batch_size = 32

# Define the model architecture
model = Sequential()

# Add the first convolutional layer
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D((2, 2)))

# Add the second convolutional layer
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Add the third convolutional layer
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Add a custom head to the base model

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(4, activation='linear'))
# Compile the model

# Compile the model with 'mse' loss and Adam optimizer with a learning rate of 0.0001
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mse', optimizer=optimizer, metrics=['accuracy'])

# Define the callback function to save the model
save_MaxPool_model = ModelCheckpoint(
    "/content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5",
    monitor='accuracy',
    save_best_only=True,
    verbose=1
)

# Directory Path
training_directory = '/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/train'
validation_directory = '/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/valid'

# Image Generator function
def image_generator(directory_path, batch_size, input_shape):
    while True:
        data = []
        train_annotation = []
        for filename in os.listdir(directory_path):
            if filename.split('.')[-1] in ['jpeg', 'jpg', 'png']:
                
                image_path = os.path.join(directory_path, filename)

                xml_path = os.path.join(directory_path, filename[:-4] +'.xml')

                tree = ET.parse(xml_path)
                root = tree.getroot()

                # Check boundbox
                boundingbox = root.find('object/bndbox')
                if boundingbox is not None:
                    X_min = int(boundingbox.find('xmin').text)
                    X_max = int(boundingbox.find('xmax').text)
                    Y_min = int(boundingbox.find('ymin').text)
                    Y_max = int(boundingbox.find('ymax').text)
                    train_annotation.append([X_min, Y_min, X_max, Y_max])

                    # Load image
                    image = cv2.imread(image_path)
                    image = cv2.resize(image, input_shape[:2])
                    data.append(image)

                    if len(data) == batch_size:
                        yield np.array(data), np.array(train_annotation) * 0.35
                        data = []
                        train_annotation = []

        if len(data) > 0:
            yield np.array(data), np.array(train_annotation) * 0.35
           
# Evaluate the performance on the validation set
train_generator = image_generator(training_directory, batch_size, input_shape)
training_steps = len(os.listdir(training_directory)) // batch_size

val_generator = image_generator(validation_directory, batch_size, input_shape)
val_steps = len(os.listdir(validation_directory)) // batch_size

# Train the model
MaxPool_model_history = model.fit(train_generator,
                                      steps_per_epoch=training_steps,
                                      epochs=100,
                                      verbose=1,
                                      validation_data=val_generator,
                                      validation_steps=val_steps,
                                      callbacks=[save_MaxPool_model])            
# Save the history variable to a file in your Google Drive
with open('/content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPool_model_history.pkl', 'wb') as f:
    pickle.dump(MaxPool_model_history.history, f)
# Out:
# Epoch 1/100
# 62/62 [==============================] - ETA: 0s - loss: 3052.9602 - accuracy: 0.6775
# Epoch 1: accuracy improved from -inf to 0.67752, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 43s 487ms/step - loss: 3052.9602 - accuracy: 0.6775 - val_loss: 1095.8883 - val_accuracy: 0.7674
# Epoch 2/100
# 62/62 [==============================] - ETA: 0s - loss: 858.0762 - accuracy: 0.8054
# Epoch 2: accuracy improved from 0.67752 to 0.80544, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 28s 462ms/step - loss: 858.0762 - accuracy: 0.8054 - val_loss: 857.5478 - val_accuracy: 0.7882
# Epoch 3/100
# 62/62 [==============================] - ETA: 0s - loss: 518.8838 - accuracy: 0.8619
# Epoch 3: accuracy improved from 0.80544 to 0.86191, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 25s 415ms/step - loss: 518.8838 - accuracy: 0.8619 - val_loss: 766.3665 - val_accuracy: 0.7917
# Epoch 4/100
# 62/62 [==============================] - ETA: 0s - loss: 356.2666 - accuracy: 0.8814
# Epoch 4: accuracy improved from 0.86191 to 0.88142, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 27s 447ms/step - loss: 356.2666 - accuracy: 0.8814 - val_loss: 795.3040 - val_accuracy: 0.7882
# Epoch 5/100
# 62/62 [==============================] - ETA: 0s - loss: 453.1866 - accuracy: 0.8183
# Epoch 5: accuracy did not improve from 0.88142
# 62/62 [==============================] - 23s 380ms/step - loss: 453.1866 - accuracy: 0.8183 - val_loss: 853.7798 - val_accuracy: 0.7188
# Epoch 6/100
# 62/62 [==============================] - ETA: 0s - loss: 340.2245 - accuracy: 0.8439
# Epoch 6: accuracy did not improve from 0.88142
# 62/62 [==============================] - 27s 440ms/step - loss: 340.2245 - accuracy: 0.8439 - val_loss: 925.4064 - val_accuracy: 0.7674
# Epoch 7/100
# 62/62 [==============================] - ETA: 0s - loss: 358.8558 - accuracy: 0.8080
# Epoch 7: accuracy did not improve from 0.88142
# 62/62 [==============================] - 23s 368ms/step - loss: 358.8558 - accuracy: 0.8080 - val_loss: 970.9636 - val_accuracy: 0.6875
# Epoch 8/100
# 62/62 [==============================] - ETA: 0s - loss: 324.6449 - accuracy: 0.8306
# Epoch 8: accuracy did not improve from 0.88142
# 62/62 [==============================] - 21s 349ms/step - loss: 324.6449 - accuracy: 0.8306 - val_loss: 921.0526 - val_accuracy: 0.7743
# Epoch 9/100
# 62/62 [==============================] - ETA: 0s - loss: 204.1519 - accuracy: 0.8881
# Epoch 9: accuracy improved from 0.88142 to 0.88809, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 26s 421ms/step - loss: 204.1519 - accuracy: 0.8881 - val_loss: 825.8518 - val_accuracy: 0.7847
# Epoch 10/100
# 62/62 [==============================] - ETA: 0s - loss: 147.1994 - accuracy: 0.9117
# Epoch 10: accuracy improved from 0.88809 to 0.91170, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 30s 488ms/step - loss: 147.1994 - accuracy: 0.9117 - val_loss: 856.3919 - val_accuracy: 0.7882
# Epoch 11/100
# 62/62 [==============================] - ETA: 0s - loss: 110.1061 - accuracy: 0.9127
# Epoch 11: accuracy improved from 0.91170 to 0.91273, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 26s 427ms/step - loss: 110.1061 - accuracy: 0.9127 - val_loss: 868.7141 - val_accuracy: 0.7604
# Epoch 12/100
# 62/62 [==============================] - ETA: 0s - loss: 131.4382 - accuracy: 0.9091
# Epoch 12: accuracy did not improve from 0.91273
# 62/62 [==============================] - 24s 400ms/step - loss: 131.4382 - accuracy: 0.9091 - val_loss: 891.5810 - val_accuracy: 0.7778
# Epoch 13/100
# 62/62 [==============================] - ETA: 0s - loss: 201.3542 - accuracy: 0.8696
# Epoch 13: accuracy did not improve from 0.91273
# 62/62 [==============================] - 27s 440ms/step - loss: 201.3542 - accuracy: 0.8696 - val_loss: 1087.7031 - val_accuracy: 0.7917
# Epoch 14/100
# 62/62 [==============================] - ETA: 0s - loss: 470.5304 - accuracy: 0.8578
# Epoch 14: accuracy did not improve from 0.91273
# 62/62 [==============================] - 28s 458ms/step - loss: 470.5304 - accuracy: 0.8578 - val_loss: 1433.3882 - val_accuracy: 0.7674
# Epoch 15/100
# 62/62 [==============================] - ETA: 0s - loss: 515.0095 - accuracy: 0.8727
# Epoch 15: accuracy did not improve from 0.91273
# 62/62 [==============================] - 27s 440ms/step - loss: 515.0095 - accuracy: 0.8727 - val_loss: 1071.5854 - val_accuracy: 0.7986
# Epoch 16/100
# 62/62 [==============================] - ETA: 0s - loss: 261.9518 - accuracy: 0.8783
# Epoch 16: accuracy did not improve from 0.91273
# 62/62 [==============================] - 27s 441ms/step - loss: 261.9518 - accuracy: 0.8783 - val_loss: 1059.7091 - val_accuracy: 0.7396
# Epoch 17/100
# 62/62 [==============================] - ETA: 0s - loss: 219.1493 - accuracy: 0.8581
# Epoch 17: accuracy did not improve from 0.91273
# 62/62 [==============================] - 27s 442ms/step - loss: 219.1493 - accuracy: 0.8581 - val_loss: 879.2101 - val_accuracy: 0.7500
# Epoch 18/100
# 62/62 [==============================] - ETA: 0s - loss: 170.7435 - accuracy: 0.8614
# Epoch 18: accuracy did not improve from 0.91273
# 62/62 [==============================] - 27s 441ms/step - loss: 170.7435 - accuracy: 0.8614 - val_loss: 865.8975 - val_accuracy: 0.7674
# Epoch 19/100
# 62/62 [==============================] - ETA: 0s - loss: 107.6910 - accuracy: 0.8932
# Epoch 19: accuracy did not improve from 0.91273
# 62/62 [==============================] - 28s 456ms/step - loss: 107.6910 - accuracy: 0.8932 - val_loss: 809.0228 - val_accuracy: 0.8160
# Epoch 20/100
# 62/62 [==============================] - ETA: 0s - loss: 71.0384 - accuracy: 0.9266
# Epoch 20: accuracy improved from 0.91273 to 0.92659, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 29s 480ms/step - loss: 71.0384 - accuracy: 0.9266 - val_loss: 776.1642 - val_accuracy: 0.8160
# Epoch 21/100
# 62/62 [==============================] - ETA: 0s - loss: 63.5655 - accuracy: 0.9420
# Epoch 21: accuracy improved from 0.92659 to 0.94199, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 26s 424ms/step - loss: 63.5655 - accuracy: 0.9420 - val_loss: 821.3946 - val_accuracy: 0.7812
# Epoch 22/100
# 62/62 [==============================] - ETA: 0s - loss: 68.1694 - accuracy: 0.9430
# Epoch 22: accuracy improved from 0.94199 to 0.94302, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 30s 494ms/step - loss: 68.1694 - accuracy: 0.9430 - val_loss: 812.0807 - val_accuracy: 0.8056
# Epoch 23/100
# 62/62 [==============================] - ETA: 0s - loss: 81.8333 - accuracy: 0.9379
# Epoch 23: accuracy did not improve from 0.94302
# 62/62 [==============================] - 24s 396ms/step - loss: 81.8333 - accuracy: 0.9379 - val_loss: 1022.3585 - val_accuracy: 0.7431
# Epoch 24/100
# 62/62 [==============================] - ETA: 0s - loss: 138.4937 - accuracy: 0.9168
# Epoch 24: accuracy did not improve from 0.94302
# 62/62 [==============================] - 23s 370ms/step - loss: 138.4937 - accuracy: 0.9168 - val_loss: 799.3938 - val_accuracy: 0.7986
# Epoch 25/100
# 62/62 [==============================] - ETA: 0s - loss: 173.0822 - accuracy: 0.9025
# Epoch 25: accuracy did not improve from 0.94302
# 62/62 [==============================] - 21s 349ms/step - loss: 173.0822 - accuracy: 0.9025 - val_loss: 899.5671 - val_accuracy: 0.7882
# Epoch 26/100
# 62/62 [==============================] - ETA: 0s - loss: 175.0724 - accuracy: 0.8758
# Epoch 26: accuracy did not improve from 0.94302
# 62/62 [==============================] - 23s 371ms/step - loss: 175.0724 - accuracy: 0.8758 - val_loss: 1087.5204 - val_accuracy: 0.7951
# Epoch 27/100
# 62/62 [==============================] - ETA: 0s - loss: 214.8841 - accuracy: 0.8783
# Epoch 27: accuracy did not improve from 0.94302
# 62/62 [==============================] - 22s 357ms/step - loss: 214.8841 - accuracy: 0.8783 - val_loss: 1184.6331 - val_accuracy: 0.7847
# Epoch 28/100
# 62/62 [==============================] - ETA: 0s - loss: 261.2655 - accuracy: 0.8824
# Epoch 28: accuracy did not improve from 0.94302
# 62/62 [==============================] - 22s 362ms/step - loss: 261.2655 - accuracy: 0.8824 - val_loss: 857.1687 - val_accuracy: 0.7778
# Epoch 29/100
# 62/62 [==============================] - ETA: 0s - loss: 393.2204 - accuracy: 0.8814
# Epoch 29: accuracy did not improve from 0.94302
# 62/62 [==============================] - 23s 384ms/step - loss: 393.2204 - accuracy: 0.8814 - val_loss: 1830.7120 - val_accuracy: 0.6979
# Epoch 30/100
# 62/62 [==============================] - ETA: 0s - loss: 657.5224 - accuracy: 0.8927
# Epoch 30: accuracy did not improve from 0.94302
# 62/62 [==============================] - 22s 354ms/step - loss: 657.5224 - accuracy: 0.8927 - val_loss: 846.7355 - val_accuracy: 0.7917
# Epoch 31/100
# 62/62 [==============================] - ETA: 0s - loss: 687.1123 - accuracy: 0.8994
# Epoch 31: accuracy did not improve from 0.94302
# 62/62 [==============================] - 22s 361ms/step - loss: 687.1123 - accuracy: 0.8994 - val_loss: 941.7545 - val_accuracy: 0.7986
# Epoch 32/100
# 62/62 [==============================] - ETA: 0s - loss: 288.8676 - accuracy: 0.9328
# Epoch 32: accuracy did not improve from 0.94302
# 62/62 [==============================] - 22s 368ms/step - loss: 288.8676 - accuracy: 0.9328 - val_loss: 749.2004 - val_accuracy: 0.8021
# Epoch 33/100
# 62/62 [==============================] - ETA: 0s - loss: 134.5345 - accuracy: 0.9461
# Epoch 33: accuracy improved from 0.94302 to 0.94608, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 24s 399ms/step - loss: 134.5345 - accuracy: 0.9461 - val_loss: 779.7517 - val_accuracy: 0.7951
# Epoch 34/100
# 62/62 [==============================] - ETA: 0s - loss: 80.3764 - accuracy: 0.9564
# Epoch 34: accuracy improved from 0.94608 to 0.95637, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 26s 425ms/step - loss: 80.3764 - accuracy: 0.9564 - val_loss: 791.3652 - val_accuracy: 0.7917
# Epoch 35/100
# 62/62 [==============================] - ETA: 0s - loss: 54.3080 - accuracy: 0.9630
# Epoch 35: accuracy improved from 0.95637 to 0.96304, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 27s 434ms/step - loss: 54.3080 - accuracy: 0.9630 - val_loss: 760.8255 - val_accuracy: 0.7882
# Epoch 36/100
# 62/62 [==============================] - ETA: 0s - loss: 38.1934 - accuracy: 0.9671
# Epoch 36: accuracy improved from 0.96304 to 0.96715, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 26s 433ms/step - loss: 38.1934 - accuracy: 0.9671 - val_loss: 739.2172 - val_accuracy: 0.7917
# Epoch 37/100
# 62/62 [==============================] - ETA: 0s - loss: 29.0786 - accuracy: 0.9728
# Epoch 37: accuracy improved from 0.96715 to 0.97279, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 27s 444ms/step - loss: 29.0786 - accuracy: 0.9728 - val_loss: 734.7384 - val_accuracy: 0.7917
# Epoch 38/100
# 62/62 [==============================] - ETA: 0s - loss: 23.0983 - accuracy: 0.9743
# Epoch 38: accuracy improved from 0.97279 to 0.97433, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 27s 434ms/step - loss: 23.0983 - accuracy: 0.9743 - val_loss: 736.6371 - val_accuracy: 0.7986
# Epoch 39/100
# 62/62 [==============================] - ETA: 0s - loss: 20.2136 - accuracy: 0.9810
# Epoch 39: accuracy improved from 0.97433 to 0.98101, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 31s 504ms/step - loss: 20.2136 - accuracy: 0.9810 - val_loss: 738.5919 - val_accuracy: 0.7847
# Epoch 40/100
# 62/62 [==============================] - ETA: 0s - loss: 17.9172 - accuracy: 0.9836
# Epoch 40: accuracy improved from 0.98101 to 0.98357, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 27s 436ms/step - loss: 17.9172 - accuracy: 0.9836 - val_loss: 739.5621 - val_accuracy: 0.7778
# Epoch 41/100
# 62/62 [==============================] - ETA: 0s - loss: 16.5894 - accuracy: 0.9856
# Epoch 41: accuracy improved from 0.98357 to 0.98563, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 27s 434ms/step - loss: 16.5894 - accuracy: 0.9856 - val_loss: 740.4901 - val_accuracy: 0.7708
# Epoch 42/100
# 62/62 [==============================] - ETA: 0s - loss: 14.6658 - accuracy: 0.9867
# Epoch 42: accuracy improved from 0.98563 to 0.98665, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 26s 422ms/step - loss: 14.6658 - accuracy: 0.9867 - val_loss: 740.4883 - val_accuracy: 0.7708
# Epoch 43/100
# 62/62 [==============================] - ETA: 0s - loss: 14.4825 - accuracy: 0.9872
# Epoch 43: accuracy improved from 0.98665 to 0.98717, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 26s 422ms/step - loss: 14.4825 - accuracy: 0.9872 - val_loss: 739.9023 - val_accuracy: 0.7674
# Epoch 44/100
# 62/62 [==============================] - ETA: 0s - loss: 13.7120 - accuracy: 0.9902
# Epoch 44: accuracy improved from 0.98717 to 0.99025, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 26s 419ms/step - loss: 13.7120 - accuracy: 0.9902 - val_loss: 739.3564 - val_accuracy: 0.7708
# Epoch 45/100
# 62/62 [==============================] - ETA: 0s - loss: 13.7548 - accuracy: 0.9913
# Epoch 45: accuracy improved from 0.99025 to 0.99127, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 31s 509ms/step - loss: 13.7548 - accuracy: 0.9913 - val_loss: 739.4710 - val_accuracy: 0.7882
# Epoch 46/100
# 62/62 [==============================] - ETA: 0s - loss: 13.6089 - accuracy: 0.9933
# Epoch 46: accuracy improved from 0.99127 to 0.99333, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 26s 427ms/step - loss: 13.6089 - accuracy: 0.9933 - val_loss: 741.2089 - val_accuracy: 0.7917
# Epoch 47/100
# 62/62 [==============================] - ETA: 0s - loss: 12.6264 - accuracy: 0.9954
# Epoch 47: accuracy improved from 0.99333 to 0.99538, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5
# 62/62 [==============================] - 27s 449ms/step - loss: 12.6264 - accuracy: 0.9954 - val_loss: 750.1324 - val_accuracy: 0.8021
# Epoch 48/100
# 62/62 [==============================] - ETA: 0s - loss: 14.6223 - accuracy: 0.9913
# Epoch 48: accuracy did not improve from 0.99538
# 62/62 [==============================] - 28s 453ms/step - loss: 14.6223 - accuracy: 0.9913 - val_loss: 751.5759 - val_accuracy: 0.8090
# Epoch 49/100
# 62/62 [==============================] - ETA: 0s - loss: 16.9502 - accuracy: 0.9858
# Epoch 49: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 371ms/step - loss: 16.9502 - accuracy: 0.9858 - val_loss: 773.6700 - val_accuracy: 0.8090
# Epoch 50/100
# 62/62 [==============================] - ETA: 0s - loss: 22.3740 - accuracy: 0.9800
# Epoch 50: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 374ms/step - loss: 22.3740 - accuracy: 0.9800 - val_loss: 824.2283 - val_accuracy: 0.8056
# Epoch 51/100
# 62/62 [==============================] - ETA: 0s - loss: 38.6723 - accuracy: 0.9553
# Epoch 51: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 369ms/step - loss: 38.6723 - accuracy: 0.9553 - val_loss: 858.1761 - val_accuracy: 0.8090
# Epoch 52/100
# 62/62 [==============================] - ETA: 0s - loss: 86.7135 - accuracy: 0.9117
# Epoch 52: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 371ms/step - loss: 86.7135 - accuracy: 0.9117 - val_loss: 908.7919 - val_accuracy: 0.7326
# Epoch 53/100
# 62/62 [==============================] - ETA: 0s - loss: 137.6609 - accuracy: 0.8629
# Epoch 53: accuracy did not improve from 0.99538
# 62/62 [==============================] - 21s 351ms/step - loss: 137.6609 - accuracy: 0.8629 - val_loss: 901.2069 - val_accuracy: 0.7917
# Epoch 54/100
# 62/62 [==============================] - ETA: 0s - loss: 112.7293 - accuracy: 0.8835
# Epoch 54: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 369ms/step - loss: 112.7293 - accuracy: 0.8835 - val_loss: 805.8607 - val_accuracy: 0.7743
# Epoch 55/100
# 62/62 [==============================] - ETA: 0s - loss: 94.3132 - accuracy: 0.9132
# Epoch 55: accuracy did not improve from 0.99538
# 62/62 [==============================] - 28s 459ms/step - loss: 94.3132 - accuracy: 0.9132 - val_loss: 879.3905 - val_accuracy: 0.7847
# Epoch 56/100
# 62/62 [==============================] - ETA: 0s - loss: 117.9214 - accuracy: 0.9338
# Epoch 56: accuracy did not improve from 0.99538
# 62/62 [==============================] - 22s 367ms/step - loss: 117.9214 - accuracy: 0.9338 - val_loss: 1057.2262 - val_accuracy: 0.7708
# Epoch 57/100
# 62/62 [==============================] - ETA: 0s - loss: 208.6323 - accuracy: 0.9420
# Epoch 57: accuracy did not improve from 0.99538
# 62/62 [==============================] - 22s 357ms/step - loss: 208.6323 - accuracy: 0.9420 - val_loss: 810.8929 - val_accuracy: 0.7639
# Epoch 58/100
# 62/62 [==============================] - ETA: 0s - loss: 279.1540 - accuracy: 0.9338
# Epoch 58: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 372ms/step - loss: 279.1540 - accuracy: 0.9338 - val_loss: 1389.7969 - val_accuracy: 0.7917
# Epoch 59/100
# 62/62 [==============================] - ETA: 0s - loss: 425.4987 - accuracy: 0.9158
# Epoch 59: accuracy did not improve from 0.99538
# 62/62 [==============================] - 27s 442ms/step - loss: 425.4987 - accuracy: 0.9158 - val_loss: 1158.4839 - val_accuracy: 0.7847
# Epoch 60/100
# 62/62 [==============================] - ETA: 0s - loss: 345.7982 - accuracy: 0.9328
# Epoch 60: accuracy did not improve from 0.99538
# 62/62 [==============================] - 28s 455ms/step - loss: 345.7982 - accuracy: 0.9328 - val_loss: 820.6367 - val_accuracy: 0.7778
# Epoch 61/100
# 62/62 [==============================] - ETA: 0s - loss: 118.1908 - accuracy: 0.9543
# Epoch 61: accuracy did not improve from 0.99538
# 62/62 [==============================] - 22s 366ms/step - loss: 118.1908 - accuracy: 0.9543 - val_loss: 750.3187 - val_accuracy: 0.8090
# Epoch 62/100
# 62/62 [==============================] - ETA: 0s - loss: 26.4580 - accuracy: 0.9651
# Epoch 62: accuracy did not improve from 0.99538
# 62/62 [==============================] - 22s 356ms/step - loss: 26.4580 - accuracy: 0.9651 - val_loss: 746.7222 - val_accuracy: 0.8125
# Epoch 63/100
# 62/62 [==============================] - ETA: 0s - loss: 15.9129 - accuracy: 0.9748
# Epoch 63: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 369ms/step - loss: 15.9129 - accuracy: 0.9748 - val_loss: 745.8079 - val_accuracy: 0.8090
# Epoch 64/100
# 62/62 [==============================] - ETA: 0s - loss: 15.2533 - accuracy: 0.9692
# Epoch 64: accuracy did not improve from 0.99538
# 62/62 [==============================] - 22s 356ms/step - loss: 15.2533 - accuracy: 0.9692 - val_loss: 742.5290 - val_accuracy: 0.8125
# Epoch 65/100
# 62/62 [==============================] - ETA: 0s - loss: 13.4023 - accuracy: 0.9736
# Epoch 65: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 370ms/step - loss: 13.4023 - accuracy: 0.9736 - val_loss: 745.0048 - val_accuracy: 0.7986
# Epoch 66/100
# 62/62 [==============================] - ETA: 0s - loss: 12.0229 - accuracy: 0.9738
# Epoch 66: accuracy did not improve from 0.99538
# 62/62 [==============================] - 28s 464ms/step - loss: 12.0229 - accuracy: 0.9738 - val_loss: 743.8088 - val_accuracy: 0.7812
# Epoch 67/100
# 62/62 [==============================] - ETA: 0s - loss: 11.2490 - accuracy: 0.9733
# Epoch 67: accuracy did not improve from 0.99538
# 62/62 [==============================] - 22s 366ms/step - loss: 11.2490 - accuracy: 0.9733 - val_loss: 743.2267 - val_accuracy: 0.7778
# Epoch 68/100
# 62/62 [==============================] - ETA: 0s - loss: 11.2217 - accuracy: 0.9759
# Epoch 68: accuracy did not improve from 0.99538
# 62/62 [==============================] - 22s 357ms/step - loss: 11.2217 - accuracy: 0.9759 - val_loss: 747.1424 - val_accuracy: 0.7674
# Epoch 69/100
# 62/62 [==============================] - ETA: 0s - loss: 12.8286 - accuracy: 0.9738
# Epoch 69: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 368ms/step - loss: 12.8286 - accuracy: 0.9738 - val_loss: 761.7312 - val_accuracy: 0.7674
# Epoch 70/100
# 62/62 [==============================] - ETA: 0s - loss: 17.6970 - accuracy: 0.9707
# Epoch 70: accuracy did not improve from 0.99538
# 62/62 [==============================] - 27s 440ms/step - loss: 17.6970 - accuracy: 0.9707 - val_loss: 739.5740 - val_accuracy: 0.7708
# Epoch 71/100
# 62/62 [==============================] - ETA: 0s - loss: 22.0716 - accuracy: 0.9697
# Epoch 71: accuracy did not improve from 0.99538
# 62/62 [==============================] - 24s 384ms/step - loss: 22.0716 - accuracy: 0.9697 - val_loss: 775.1147 - val_accuracy: 0.7882
# Epoch 72/100
# 62/62 [==============================] - ETA: 0s - loss: 31.0390 - accuracy: 0.9718
# Epoch 72: accuracy did not improve from 0.99538
# 62/62 [==============================] - 21s 350ms/step - loss: 31.0390 - accuracy: 0.9718 - val_loss: 774.3148 - val_accuracy: 0.8021
# Epoch 73/100
# 62/62 [==============================] - ETA: 0s - loss: 47.0482 - accuracy: 0.9646
# Epoch 73: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 369ms/step - loss: 47.0482 - accuracy: 0.9646 - val_loss: 836.8619 - val_accuracy: 0.7917
# Epoch 74/100
# 62/62 [==============================] - ETA: 0s - loss: 77.9510 - accuracy: 0.9656
# Epoch 74: accuracy did not improve from 0.99538
# 62/62 [==============================] - 27s 440ms/step - loss: 77.9510 - accuracy: 0.9656 - val_loss: 874.4361 - val_accuracy: 0.8125
# Epoch 75/100
# 62/62 [==============================] - ETA: 0s - loss: 124.0306 - accuracy: 0.9574
# Epoch 75: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 370ms/step - loss: 124.0306 - accuracy: 0.9574 - val_loss: 813.8286 - val_accuracy: 0.7986
# Epoch 76/100
# 62/62 [==============================] - ETA: 0s - loss: 177.3691 - accuracy: 0.9363
# Epoch 76: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 374ms/step - loss: 177.3691 - accuracy: 0.9363 - val_loss: 920.2854 - val_accuracy: 0.7847
# Epoch 77/100
# 62/62 [==============================] - ETA: 0s - loss: 106.1577 - accuracy: 0.9512
# Epoch 77: accuracy did not improve from 0.99538
# 62/62 [==============================] - 22s 367ms/step - loss: 106.1577 - accuracy: 0.9512 - val_loss: 839.3582 - val_accuracy: 0.7951
# Epoch 78/100
# 62/62 [==============================] - ETA: 0s - loss: 71.3405 - accuracy: 0.9682
# Epoch 78: accuracy did not improve from 0.99538
# 62/62 [==============================] - 22s 363ms/step - loss: 71.3405 - accuracy: 0.9682 - val_loss: 839.9528 - val_accuracy: 0.7917
# Epoch 79/100
# 62/62 [==============================] - ETA: 0s - loss: 47.5522 - accuracy: 0.9707
# Epoch 79: accuracy did not improve from 0.99538
# 62/62 [==============================] - 22s 361ms/step - loss: 47.5522 - accuracy: 0.9707 - val_loss: 773.0605 - val_accuracy: 0.7847
# Epoch 80/100
# 62/62 [==============================] - ETA: 0s - loss: 51.6603 - accuracy: 0.9502
# Epoch 80: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 372ms/step - loss: 51.6603 - accuracy: 0.9502 - val_loss: 769.0671 - val_accuracy: 0.7847
# Epoch 81/100
# 62/62 [==============================] - ETA: 0s - loss: 42.1377 - accuracy: 0.9542
# Epoch 81: accuracy did not improve from 0.99538
# 62/62 [==============================] - 22s 361ms/step - loss: 42.1377 - accuracy: 0.9542 - val_loss: 790.8790 - val_accuracy: 0.7743
# Epoch 82/100
# 62/62 [==============================] - ETA: 0s - loss: 43.3313 - accuracy: 0.9615
# Epoch 82: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 376ms/step - loss: 43.3313 - accuracy: 0.9615 - val_loss: 772.3878 - val_accuracy: 0.7917
# Epoch 83/100
# 62/62 [==============================] - ETA: 0s - loss: 52.6298 - accuracy: 0.9471
# Epoch 83: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 368ms/step - loss: 52.6298 - accuracy: 0.9471 - val_loss: 810.1091 - val_accuracy: 0.7812
# Epoch 84/100
# 62/62 [==============================] - ETA: 0s - loss: 43.4855 - accuracy: 0.9440
# Epoch 84: accuracy did not improve from 0.99538
# 62/62 [==============================] - 22s 357ms/step - loss: 43.4855 - accuracy: 0.9440 - val_loss: 814.4105 - val_accuracy: 0.7951
# Epoch 85/100
# 62/62 [==============================] - ETA: 0s - loss: 44.5773 - accuracy: 0.9507
# Epoch 85: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 370ms/step - loss: 44.5773 - accuracy: 0.9507 - val_loss: 837.7439 - val_accuracy: 0.8021
# Epoch 86/100
# 62/62 [==============================] - ETA: 0s - loss: 52.4966 - accuracy: 0.9307
# Epoch 86: accuracy did not improve from 0.99538
# 62/62 [==============================] - 27s 440ms/step - loss: 52.4966 - accuracy: 0.9307 - val_loss: 801.1843 - val_accuracy: 0.7917
# Epoch 87/100
# 62/62 [==============================] - ETA: 0s - loss: 47.3005 - accuracy: 0.9317
# Epoch 87: accuracy did not improve from 0.99538
# 62/62 [==============================] - 28s 458ms/step - loss: 47.3005 - accuracy: 0.9317 - val_loss: 806.2688 - val_accuracy: 0.7951
# Epoch 88/100
# 62/62 [==============================] - ETA: 0s - loss: 49.3296 - accuracy: 0.9435
# Epoch 88: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 370ms/step - loss: 49.3296 - accuracy: 0.9435 - val_loss: 789.2921 - val_accuracy: 0.7986
# Epoch 89/100
# 62/62 [==============================] - ETA: 0s - loss: 43.5882 - accuracy: 0.9405
# Epoch 89: accuracy did not improve from 0.99538
# 62/62 [==============================] - 22s 354ms/step - loss: 43.5882 - accuracy: 0.9405 - val_loss: 786.2639 - val_accuracy: 0.7951
# Epoch 90/100
# 62/62 [==============================] - ETA: 0s - loss: 53.5751 - accuracy: 0.9476
# Epoch 90: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 368ms/step - loss: 53.5751 - accuracy: 0.9476 - val_loss: 851.7401 - val_accuracy: 0.7708
# Epoch 91/100
# 62/62 [==============================] - ETA: 0s - loss: 56.9552 - accuracy: 0.9271
# Epoch 91: accuracy did not improve from 0.99538
# 62/62 [==============================] - 27s 442ms/step - loss: 56.9552 - accuracy: 0.9271 - val_loss: 775.3213 - val_accuracy: 0.7604
# Epoch 92/100
# 62/62 [==============================] - ETA: 0s - loss: 76.8348 - accuracy: 0.9369
# Epoch 92: accuracy did not improve from 0.99538
# 62/62 [==============================] - 29s 467ms/step - loss: 76.8348 - accuracy: 0.9369 - val_loss: 824.7595 - val_accuracy: 0.7708
# Epoch 93/100
# 62/62 [==============================] - ETA: 0s - loss: 79.7833 - accuracy: 0.9446
# Epoch 93: accuracy did not improve from 0.99538
# 62/62 [==============================] - 29s 476ms/step - loss: 79.7833 - accuracy: 0.9446 - val_loss: 962.3378 - val_accuracy: 0.7986
# Epoch 94/100
# 62/62 [==============================] - ETA: 0s - loss: 95.0695 - accuracy: 0.9456
# Epoch 94: accuracy did not improve from 0.99538
# 62/62 [==============================] - 27s 443ms/step - loss: 95.0695 - accuracy: 0.9456 - val_loss: 785.4983 - val_accuracy: 0.7847
# Epoch 95/100
# 62/62 [==============================] - ETA: 0s - loss: 77.4063 - accuracy: 0.9379
# Epoch 95: accuracy did not improve from 0.99538
# 62/62 [==============================] - 28s 463ms/step - loss: 77.4063 - accuracy: 0.9379 - val_loss: 838.8242 - val_accuracy: 0.7986
# Epoch 96/100
# 62/62 [==============================] - ETA: 0s - loss: 64.6115 - accuracy: 0.9194
# Epoch 96: accuracy did not improve from 0.99538
# 62/62 [==============================] - 28s 451ms/step - loss: 64.6115 - accuracy: 0.9194 - val_loss: 847.3088 - val_accuracy: 0.7986
# Epoch 97/100
# 62/62 [==============================] - ETA: 0s - loss: 52.3254 - accuracy: 0.9283
# Epoch 97: accuracy did not improve from 0.99538
# 62/62 [==============================] - 30s 498ms/step - loss: 52.3254 - accuracy: 0.9283 - val_loss: 798.4485 - val_accuracy: 0.8021
# Epoch 98/100
# 62/62 [==============================] - ETA: 0s - loss: 54.7354 - accuracy: 0.9507
# Epoch 98: accuracy did not improve from 0.99538
# 62/62 [==============================] - 25s 415ms/step - loss: 54.7354 - accuracy: 0.9507 - val_loss: 818.8252 - val_accuracy: 0.7812
# Epoch 99/100
# 62/62 [==============================] - ETA: 0s - loss: 50.2191 - accuracy: 0.9487
# Epoch 99: accuracy did not improve from 0.99538
# 62/62 [==============================] - 23s 368ms/step - loss: 50.2191 - accuracy: 0.9487 - val_loss: 836.9033 - val_accuracy: 0.7778
# Epoch 100/100
# 62/62 [==============================] - ETA: 0s - loss: 55.9629 - accuracy: 0.9446
# Epoch 100: accuracy did not improve from 0.99538
# 62/62 [==============================] - 22s 363ms/step - loss: 55.9629 - accuracy: 0.9446 - val_loss: 855.2326 - val_accuracy: 0.7639

# %% [markdown]
# ###**Test Model for detecting output**

# %%
import matplotlib.pyplot as plt

#Load model
MaxPoolModel = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPoolModel1.h5')

# Directory Path
test_directory = r'/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/test'

# Data Generator for test set
test_generator = image_generator(test_directory, batch_size, input_shape)
images, annotations = next(test_generator)

model_predictions = MaxPoolModel.predict(images)
for i in range(0, len(images), 4):
    fig, axs = plt.subplots(1, 4, figsize=(20, 10))
    for j in range(4):
        if i+j >= len(images):
            break
        image = images[i+j].astype('uint8')
        annotation = annotations[i+j]
        pred = model_predictions[i+j]
        X_min, Y_min, X_max, Y_max = annotation.astype('int')
        X_min1, Y_min1, X_max1, Y_max1 = pred.astype('int')
        cv2.rectangle(image, (X_min, Y_min), (X_max, Y_max), (0, 255, 0), 2)
        cv2.rectangle(image, (X_min1, Y_min1), (X_max1, Y_max1), (255,0,0), 2)
        cv2.putText(image, 'Number Plate', (X_min1, Y_min1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)
        axs[j].imshow(image)
        axs[j].axis('off')
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ###**Performance Evaluation**

# %%
# Directory Path
training_directory = '/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/train'
validation_directory = '/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/valid'
test_directory = '/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/test'

#Data Generator
train_generator = image_generator(training_directory, batch_size, input_shape)
training_steps = len(os.listdir(training_directory)) // batch_size

val_generator = image_generator(validation_directory, batch_size, input_shape)
val_steps = len(os.listdir(validation_directory)) // batch_size

test_generator = image_generator(test_directory, batch_size, input_shape)
test_steps = len(os.listdir(test_directory)) // batch_size

# Evaluate the performance on the validation set

validation_loss, validation_accuracy = MaxPoolModel.evaluate(val_generator, steps=val_steps)

print("Validation Loss:", validation_loss)
print("Validation Accuracy:", validation_accuracy)

# Evaluate the performance on the training set
training_loss, training_accuracy = MaxPoolModel.evaluate(train_generator, steps=training_steps)

print("Training Loss:", training_loss)
print("Training Accuracy:", training_accuracy)

# Evaluate the performance on the test set
test_loss, test_accuracy = MaxPoolModel.evaluate(test_generator, steps=test_steps)
print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
# Out:
# 18/18 [==============================] - 6s 313ms/step - loss: 750.1323 - accuracy: 0.8021
# Validation Loss: 750.13232421875
# Validation Accuracy: 0.8020833134651184
# 62/62 [==============================] - 23s 379ms/step - loss: 24.1397 - accuracy: 0.9700
# Training Loss: 24.139711380004883
# Training Accuracy: 0.9699898362159729
# 9/9 [==============================] - 4s 441ms/step - loss: 782.2273 - accuracy: 0.8095
# Test loss: 782.227294921875
# Test accuracy: 0.8095238208770752

# %% [markdown]
# ###**Visual Representation on Trainging and Validation**

# %%
import pickle

with open('/content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/MaxPool_model_history.pkl', 'rb') as f:
    history = pickle.load(f)

# Plot the accuracy over epochs
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accurracy', 'Validation Accurracy'], loc='upper left')
plt.show()

# Plot the loss over epochs
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper left')
plt.show()
