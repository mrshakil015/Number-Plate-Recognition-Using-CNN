# %% [markdown]
# ##**VGG19 Model**

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.optimizers import Adam
import xml.etree.ElementTree as ET
from tensorflow.keras.regularizers import l2
import pickle

# Define the input shape and batch size
input_shape = (224, 224, 3)
batch_size = 32

# Define the base model
VGG19_base_model = VGG19(input_shape=input_shape, include_top=False, weights='imagenet')

# Freeze the layers of the base model
for layer in VGG19_base_model.layers:
    layer.trainable = False

# Unfreeze the last convolutional block of the base model
for layer in VGG19_base_model.layers[-4:]:
    layer.trainable = True
# Add a custom head to the base model
x = VGG19_base_model.output
x = Flatten()(x)
x = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(x)
x = Dense(64, activation='relu', kernel_regularizer=l2(0.01))(x)
x = Dense(4, activation='linear')(x)
model = Model(inputs=VGG19_base_model.input, outputs=x)
# Compile the model

optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mse', optimizer=optimizer, metrics=['accuracy'])

# Callback to the model
save_VGG19_model = tf.keras.callbacks.ModelCheckpoint(
    "/content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/VGG19Model.h5", 
    monitor='accuracy', 
    save_best_only=True, 
    verbose=1
)
# Directory Path
training_directory = '/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/train'
validation_directory = '/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/valid'

# Image Generator function
def image_generator(directory_path, batch_size, input_shape):
    while True:
        data = []
        train_annotation = []
        for filename in os.listdir(directory_path):
            if filename.split('.')[-1] in ['jpeg', 'jpg', 'png']:
                
                image_path = os.path.join(directory_path, filename)

                xml_path = os.path.join(directory_path, filename[:-4] +'.xml')

                tree = ET.parse(xml_path)
                root = tree.getroot()

                # Check boundbox
                boundingbox = root.find('object/bndbox')
                if boundingbox is not None:
                    X_min = int(boundingbox.find('xmin').text)
                    X_max = int(boundingbox.find('xmax').text)
                    Y_min = int(boundingbox.find('ymin').text)
                    Y_max = int(boundingbox.find('ymax').text)
                    train_annotation.append([X_min, Y_min, X_max, Y_max])

                    # Load image
                    image = cv2.imread(image_path)
                    image = cv2.resize(image, input_shape[:2])
                    data.append(image)

                    if len(data) == batch_size:
                        yield np.array(data), np.array(train_annotation) * 0.35
                        data = []
                        train_annotation = []

        if len(data) > 0:
            yield np.array(data), np.array(train_annotation) * 0.35

# Evaluate the performance on the validation set
train_generator = image_generator(training_directory, batch_size, input_shape)
training_steps = len(os.listdir(training_directory)) // batch_size

val_generator = image_generator(validation_directory, batch_size, input_shape)
val_steps = len(os.listdir(validation_directory)) // batch_size

# Train the model
VGG19_model_history = model.fit(train_generator,
                                      steps_per_epoch=training_steps,
                                      epochs=100,
                                      verbose=1,
                                      validation_data=val_generator,
                                      validation_steps=val_steps,
                                      callbacks=[save_VGG19_model])          
# Save the history variable to a file in your Google Drive
with open('/content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/VGG19_model_history.pkl', 'wb') as f:
    pickle.dump(VGG19_model_history.history, f)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step
# Epoch 1/100
# 62/62 [==============================] - ETA: 0s - loss: 1569.2671 - accuracy: 0.7813
# Epoch 1: accuracy improved from -inf to 0.78128, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/VGG19Model.h5
# 62/62 [==============================] - 30s 441ms/step - loss: 1569.2671 - accuracy: 0.7813 - val_loss: 880.6272 - val_accuracy: 0.7604
# Epoch 2/100
# 62/62 [==============================] - ETA: 0s - loss: 410.5824 - accuracy: 0.8711
# Epoch 2: accuracy improved from 0.78128 to 0.87115, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/VGG19Model.h5
# 62/62 [==============================] - 33s 534ms/step - loss: 410.5824 - accuracy: 0.8711 - val_loss: 609.6168 - val_accuracy: 0.8333
# Epoch 3/100
# 62/62 [==============================] - ETA: 0s - loss: 506.9126 - accuracy: 0.8568
# Epoch 3: accuracy did not improve from 0.87115
# 62/62 [==============================] - 26s 429ms/step - loss: 506.9126 - accuracy: 0.8568 - val_loss: 1205.0231 - val_accuracy: 0.8542
# Epoch 4/100
# 62/62 [==============================] - ETA: 0s - loss: 534.0388 - accuracy: 0.8948
# Epoch 4: accuracy improved from 0.87115 to 0.89476, saving model to /content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/VGG19Model.h5
# 62/62 [==============================] - 28s 455ms/step - loss: 534.0388 - accuracy: 0.8948 - val_loss: 760.8294 - val_accuracy: 0.8229
# Epoch 5/100
# 62/62 [==============================] - ETA: 0s - loss:
# Epoch 88: accuracy did not improve from 0.98819
# 62/62 [==============================] - 30s 482ms/step - loss: 78.4276 - accuracy: 0.9728 - val_loss: 447.0071 - val_accuracy: 0.9097
# Epoch 89/100
# 62/62 [==============================] - ETA: 0s - loss: 80.0137 - accuracy: 0.9666
# Epoch 89: accuracy did not improve from 0.98819
# 62/62 [==============================] - 26s 427ms/step - loss: 80.0137 - accuracy: 0.9666 - val_loss: 661.7531 - val_accuracy: 0.8785
# Epoch 90/100
# 62/62 [==============================] - ETA: 0s - loss: 74.9717 - accuracy: 0.9615
# Epoch 90: accuracy did not improve from 0.98819
# 62/62 [==============================] - 30s 489ms/step - loss: 74.9717 - accuracy: 0.9615 - val_loss: 486.0193 - val_accuracy: 0.8993
# Epoch 91/100
# 62/62 [==============================] - ETA: 0s - loss: 84.4077 - accuracy: 0.9569
# Epoch 91: accuracy did not improve from 0.98819
# 62/62 [==============================] - 29s 479ms/step - loss: 84.4077 - accuracy: 0.9569 - val_loss: 466.9958 - val_accuracy: 0.9062
# Epoch 92/100
# 62/62 [==============================] - ETA: 0s - loss: 78.7503 - accuracy: 0.9517
# Epoch 92: accuracy did not improve from 0.98819
# 62/62 [==============================] - 29s 478ms/step - loss: 78.7503 - accuracy: 0.9517 - val_loss: 672.1225 - val_accuracy: 0.9062
# Epoch 93/100
# 62/62 [==============================] - ETA: 0s - loss: 101.3607 - accuracy: 0.9589
# Epoch 93: accuracy did not improve from 0.98819
# 62/62 [==============================] - 26s 430ms/step - loss: 101.3607 - accuracy: 0.9589 - val_loss: 469.4834 - val_accuracy: 0.9132
# Epoch 94/100
# 62/62 [==============================] - ETA: 0s - loss: 102.8428 - accuracy: 0.9605
# Epoch 94: accuracy did not improve from 0.98819
# 62/62 [==============================] - 25s 414ms/step - loss: 102.8428 - accuracy: 0.9605 - val_loss: 487.4484 - val_accuracy: 0.9028
# Epoch 95/100
# 62/62 [==============================] - ETA: 0s - loss: 104.0908 - accuracy: 0.9630
# Epoch 95: accuracy did not improve from 0.98819
# 62/62 [==============================] - 30s 483ms/step - loss: 104.0908 - accuracy: 0.9630 - val_loss: 705.3337 - val_accuracy: 0.9062
# Epoch 96/100
# 62/62 [==============================] - ETA: 0s - loss: 108.4874 - accuracy: 0.9656
# Epoch 96: accuracy did not improve from 0.98819
# 62/62 [==============================] - 25s 411ms/step - loss: 108.4874 - accuracy: 0.9656 - val_loss: 467.1416 - val_accuracy: 0.9236
# Epoch 97/100
# 62/62 [==============================] - ETA: 0s - loss: 86.8828 - accuracy: 0.9674
# Epoch 97: accuracy did not improve from 0.98819
# 62/62 [==============================] - 25s 413ms/step - loss: 86.8828 - accuracy: 0.9674 - val_loss: 473.2238 - val_accuracy: 0.9132
# Epoch 98/100
# 62/62 [==============================] - ETA: 0s - loss: 87.5538 - accuracy: 0.9682
# Epoch 98: accuracy did not improve from 0.98819
# 62/62 [==============================] - 31s 513ms/step - loss: 87.5538 - accuracy: 0.9682 - val_loss: 511.4490 - val_accuracy: 0.9062
# Epoch 99/100
# 62/62 [==============================] - ETA: 0s - loss: 71.7395 - accuracy: 0.9759
# Epoch 99: accuracy did not improve from 0.98819
# 62/62 [==============================] - 29s 479ms/step - loss: 71.7395 - accuracy: 0.9759 - val_loss: 632.2852 - val_accuracy: 0.9132
# Epoch 100/100
# 62/62 [==============================] - ETA: 0s - loss: 69.9273 - accuracy: 0.9713
# Epoch 100: accuracy did not improve from 0.98819
# 62/62 [==============================] - 25s 410ms/step - loss: 69.9273 - accuracy: 0.9713 - val_loss: 458.7199 - val_accuracy: 0.9167

# %% [markdown]
# ###**Test the model for detecting output**

# %%
import matplotlib.pyplot as plt

#Load model
VGG19Model = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/VGG19Model.h5')

# Directory Path
test_directory = r'/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/test'

# Data Generator for test set
test_generator = image_generator(test_directory, batch_size, input_shape)
images, annotations = next(test_generator)

model_predictions = VGG19Model.predict(images)
for i in range(0, len(images), 4):
    fig, axs = plt.subplots(1, 4, figsize=(20, 10))
    for j in range(4):
        if i+j >= len(images):
            break
        image = images[i+j].astype('uint8')
        annotation = annotations[i+j]
        pred = model_predictions[i+j]
        X_min, Y_min, X_max, Y_max = annotation.astype('int')
        X_min1, Y_min1, X_max1, Y_max1 = pred.astype('int')
        cv2.rectangle(image, (X_min, Y_min), (X_max, Y_max), (0, 255, 0), 2)
        cv2.rectangle(image, (X_min1, Y_min1), (X_max1, Y_max1), (255,0,0), 2)
        cv2.putText(image, 'Number Plate', (X_min1, Y_min1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)
        axs[j].imshow(image)
        axs[j].axis('off')
    plt.show()

# %% [markdown]
# ###**Performance Evaluation**

# %%
# Directory Path
training_directory = '/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/train'
validation_directory = '/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/valid'
test_directory = '/content/drive/MyDrive/Colab Notebooks/Number-Palte-Dataset/test'

#Data Generator
train_generator = image_generator(training_directory, batch_size, input_shape)
training_steps = len(os.listdir(training_directory)) // batch_size

val_generator = image_generator(validation_directory, batch_size, input_shape)
val_steps = len(os.listdir(validation_directory)) // batch_size

test_generator = image_generator(test_directory, batch_size, input_shape)
test_steps = len(os.listdir(test_directory)) // batch_size

# Evaluate the performance on the validation set

validation_loss, validation_accuracy = VGG19Model.evaluate(val_generator, steps=val_steps)

print("Validation Loss:", validation_loss)
print("Validation Accuracy:", validation_accuracy)

# Evaluate the performance on the training set
training_loss, training_accuracy = VGG19Model.evaluate(train_generator, steps=training_steps)

print("Training Loss:", training_loss)
print("Training Accuracy:", training_accuracy)

# Evaluate the performance on the test set
test_loss, test_accuracy = VGG19Model.evaluate(test_generator, steps=test_steps)
print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
# Out:
# 18/18 [==============================] - 6s 354ms/step - loss: 463.1926 - accuracy: 0.9097
# Validation Loss: 463.1925964355469
# Validation Accuracy: 0.9097222089767456
# 62/62 [==============================] - 19s 307ms/step - loss: 29.2293 - accuracy: 0.9751
# Training Loss: 29.229328155517578
# Training Accuracy: 0.9750763177871704
# 9/9 [==============================] - 3s 305ms/step - loss: 402.0530 - accuracy: 0.9011
# Test loss: 402.0530090332031
# Test accuracy: 0.901098906993866

# %% [markdown]
# ###**Visual Representation on Training and Validation**

# %%
import pickle

with open('/content/drive/MyDrive/Colab Notebooks/Number-Plate-Recognition-Model/VGG19_model_history.pkl', 'rb') as f:
    history = pickle.load(f)

# Plot the accuracy over epochs
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accurracy', 'Validation Accurracy'], loc='upper left')
plt.show()

# Plot the loss over epochs
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper left')
plt.show()
